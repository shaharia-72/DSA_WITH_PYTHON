# %% [markdown]
# <a href="https://colab.research.google.com/github/shaharia-72/DSA_WITH_PYTHON/blob/main/Array_VS_List_in_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python dont have array by default we need to import array to work. but python have list by default. for seeing that we can user help() function

# %%
import array

# %%
array = array.array('i', [1,2,3,4,10])

# %%
print(array)
# Out:
# array('i', [1, 2, 3, 4, 10])

# %%
print(type(array))
# Out:
# <class 'array.array'>

# %%
list = []

# %%
print(type(list))
# Out:
# <class 'list'>

# %%
list.append(1)
list.append("shaharia")
list.append(1.2)

# %%
print(list)
# Out:
# [1, 'shaharia', 1.2]

# %%
array.append(1.2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-462730638.py in <cell line: 0>()
# ----> 1 array.append(1.2)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
array.append(99)

# %%
print(array)
# Out:
# array('i', [1, 2, 3, 4, 10, 99])

# %% [markdown]
# ![image.png](data:image/png;base64,...)
