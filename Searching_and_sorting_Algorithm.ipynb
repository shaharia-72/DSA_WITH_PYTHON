# %% [markdown]
# <a href="https://colab.research.google.com/github/shaharia-72/DSA_WITH_PYTHON/blob/main/Searching_and_sorting_Algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
